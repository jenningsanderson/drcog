# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_json('../stats/dailySums.json')

# %%
df['time'] = pd.Series(df.index.values).apply(lambda x: pd.Timestamp(int(x)*3600*1000000000))

# %%
df
# Out:
#         jenningsanderson_imports  russdeffnerimports  mspyker_imports  \
# 427825                       NaN                 NaN              NaN
# 427826                       NaN                 NaN             67.0
# 427827                       NaN                 NaN            150.0
# 427828                       NaN                 NaN            150.0
# 427829                       NaN                 NaN           2036.0
# 427848                       NaN                 NaN              NaN
# 427849                       NaN               953.0           5792.0
# 427850                    3389.0               876.0              NaN
# 427851                       NaN                 NaN              NaN
# 427852                       NaN                 NaN              NaN
# 427865                    1078.0                 NaN              NaN
# 427871                       NaN               665.0              NaN
# ...

# %%
df.plot(kind='bar',figsize=(15,8))
